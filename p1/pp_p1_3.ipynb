# %%
from google.colab import files
import matplotlib.pyplot as plt
import cv2
import numpy as np
import time

# %%
f1 = files.upload()
# Out:
#      <input type="file" id="files-b9e01c90-823e-438d-aec6-720fd84a1120" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9e01c90-823e-438d-aec6-720fd84a1120">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ipb.png to ipb.png
# Saving p-5.png to p-5.png

# %%
def readAndShowImg(fname):
    img = cv2.imread(fname)
    cv2.imshow("img", img)
    return img


print("read images using opencv")
five = cv2.imread("p-5.png")
print(five.shape)
print(five.size)

# cv2.imshow("ims", five)
plt.imshow(five)
cv2.waitKey(0)

img = cv2.imread("ipb.png")
plt.imshow(img)

img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img)
# mengambil nilai matriksnya
# acces pixel of images per postion 
pixels = five[100,100]
print(pixels)
# Out:
# read images using opencv
# (219, 224, 3)
# 147168
# [255 255 255]
